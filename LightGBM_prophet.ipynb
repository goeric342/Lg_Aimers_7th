# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,141 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] =False

# %%
import pandas as pd
import seaborn as sns

# 한글 깨짐 방지 (Colab 한정)
#plt.rcParams['font.family'] = 'Malgun Gothic'  # 윈도우
# plt.rcParams['font.family'] = 'AppleGothic'  # Mac
plt.rcParams['font.family'] = 'NanumBarunGothic'  # Colab

# 1. 데이터 불러오기
train = pd.read_csv("train.csv")

# 2. 날짜 타입으로 변환
train['영업일자'] = pd.to_datetime(train['영업일자'])

# 3. '영업장명_메뉴명' 분리
train[['영업장명', '메뉴명']] = train['영업장명_메뉴명'].str.split('_', n=1, expand=True)

# 4. 파생 변수 생성
train['요일'] = train['영업일자'].dt.dayofweek  # 0=월, 6=일
train['월'] = train['영업일자'].dt.month
train['주말여부'] = train['요일'].apply(lambda x: 1 if x >= 5 else 0)

# 변수 수정
# 음수 매출수량 제거
train = train[train['매출수량'] >= 0].copy()

# 확인
train.tail(50)
# Out:
#              영업일자      영업장명_메뉴명  매출수량   영업장명     메뉴명  요일  월  주말여부
# 102626 2024-04-27  화담숲카페_현미뻥스크림   126  화담숲카페  현미뻥스크림   5  4     1
# 102627 2024-04-28  화담숲카페_현미뻥스크림   159  화담숲카페  현미뻥스크림   6  4     1
# 102628 2024-04-29  화담숲카페_현미뻥스크림     0  화담숲카페  현미뻥스크림   0  4     0
# 102629 2024-04-30  화담숲카페_현미뻥스크림    46  화담숲카페  현미뻥스크림   1  4     0
# 102630 2024-05-01  화담숲카페_현미뻥스크림    88  화담숲카페  현미뻥스크림   2  5     0
# 102631 2024-05-02  화담숲카페_현미뻥스크림    18  화담숲카페  현미뻥스크림   3  5     0
# 102632 2024-05-03  화담숲카페_현미뻥스크림    41  화담숲카페  현미뻥스크림   4  5     0
# 102633 2024-05-04  화담숲카페_현미뻥스크림   103  화담숲카페  현미뻥스크림   5  5     1
# 102634 2024-05-05  화담숲카페_현미뻥스크림    24  화담숲카페  현미뻥스크림   6  5     1
# 102635 2024-05-06  화담숲카페_현미뻥스크림     6  화담숲카페  현미뻥스크림   0  5     0
# 102636 2024-05-07  화담숲카페_현미뻥스크림     1  화담숲카페  현미뻥스크림   1  5     0
# 102637 2024-05-08  화담숲카페_현미뻥스크림    17  화담숲카페  현미뻥스크림   2  5     0
# 102638 2024-05-09  화담숲카페_현미뻥스크림    29  화담숲카페  현미뻥스크림   3  5     0
# 102639 2024-05-10  화담숲카페_현미뻥스크림    19  화담숲카페  현미뻥스크림   4  5     0
# 102640 2024-05-11  화담숲카페_현미뻥스크림    30  화담숲카페  현미뻥스크림   5  5     1
# 102641 2024-05-12  화담숲카페_현미뻥스크림    65  화담숲카페  현미뻥스크림   6  5     1
# 102642 2024-05-13  화담숲카페_현미뻥스크림     0  화담숲카페  현미뻥스크림   0  5     0
# 102643 2024-05-14  화담숲카페_현미뻥스크림    29  화담숲카페  현미뻥스크림   1  5     0
# 102644 2024-05-15  화담숲카페_현미뻥스크림    33  화담숲카페  현미뻥스크림   2  5     0
# 102645 2024-05-16  화담숲카페_현미뻥스크림    18  화담숲카페  현미뻥스크림   3  5     0
# 102646 2024-05-17  화담숲카페_현미뻥스크림    14  화담숲카페  현미뻥스크림   4  5     0
# 102647 2024-05-18  화담숲카페_현미뻥스크림    97  화담숲카페  현미뻥스크림   5  5     1
# 102648 2024-05-19  화담숲카페_현미뻥스크림    57  화담숲카페  현미뻥스크림   6  5     1
# 102649 2024-05-20  화담숲카페_현미뻥스크림     0  화담숲카페  현미뻥스크림   0  5     0
# 102650 2024-05-21  화담숲카페_현미뻥스크림    24  화담숲카페  현미뻥스크림   1  5     0
# 102651 2024-05-22  화담숲카페_현미뻥스크림    11  화담숲카페  현미뻥스크림   2  5     0
# 102652 2024-05-23  화담숲카페_현미뻥스크림    30  화담숲카페  현미뻥스크림   3  5     0
# 102653 2024-05-24  화담숲카페_현미뻥스크림    16  화담숲카페  현미뻥스크림   4  5     0
# 102654 2024-05-25  화담숲카페_현미뻥스크림    81  화담숲카페  현미뻥스크림   5  5     1
# 102655 2024-05-26  화담숲카페_현미뻥스크림    16  화담숲카페  현미뻥스크림   6  5     1
# 102656 2024-05-27  화담숲카페_현미뻥스크림     0  화담숲카페  현미뻥스크림   0  5     0
# 102657 2024-05-28  화담숲카페_현미뻥스크림    37  화담숲카페  현미뻥스크림   1  5     0
# 102658 2024-05-29  화담숲카페_현미뻥스크림    28  화담숲카페  현미뻥스크림   2  5     0
# 102659 2024-05-30  화담숲카페_현미뻥스크림    14  화담숲카페  현미뻥스크림   3  5     0
# 102660 2024-05-31  화담숲카페_현미뻥스크림    30  화담숲카페  현미뻥스크림   4  5     0
# 102661 2024-06-01  화담숲카페_현미뻥스크림    79  화담숲카페  현미뻥스크림   5  6     1
# 102662 2024-06-02  화담숲카페_현미뻥스크림    65  화담숲카페  현미뻥스크림   6  6     1
# 102663 2024-06-03  화담숲카페_현미뻥스크림     0  화담숲카페  현미뻥스크림   0  6     0
# 102664 2024-06-04  화담숲카페_현미뻥스크림    25  화담숲카페  현미뻥스크림   1  6     0
# 102665 2024-06-05  화담숲카페_현미뻥스크림    16  화담숲카페  현미뻥스크림   2  6     0
# 102666 2024-06-06  화담숲카페_현미뻥스크림   145  화담숲카페  현미뻥스크림   3  6     0
# 102667 2024-06-07  화담숲카페_현미뻥스크림    60  화담숲카페  현미뻥스크림   4  6     0
# 102668 2024-06-08  화담숲카페_현미뻥스크림    25  화담숲카페  현미뻥스크림   5  6     1
# 102669 2024-06-09  화담숲카페_현미뻥스크림    43  화담숲카페  현미뻥스크림   6  6     1
# 102670 2024-06-10  화담숲카페_현미뻥스크림     0  화담숲카페  현미뻥스크림   0  6     0
# 102671 2024-06-11  화담숲카페_현미뻥스크림    12  화담숲카페  현미뻥스크림   1  6     0
# 102672 2024-06-12  화담숲카페_현미뻥스크림    10  화담숲카페  현미뻥스크림   2  6     0
# 102673 2024-06-13  화담숲카페_현미뻥스크림    14  화담숲카페  현미뻥스크림   3  6     0
# 102674 2024-06-14  화담숲카페_현미뻥스크림    12  화담숲카페  현미뻥스크림   4  6     0
# 102675 2024-06-15  화담숲카페_현미뻥스크림    60  화담숲카페  현미뻥스크림   5  6     1

# %%
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102662 entries, 0 to 102675
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   영업일자      102662 non-null  datetime64[ns]
#  1   영업장명_메뉴명  102662 non-null  object
#  2   매출수량      102662 non-null  int64
#  3   영업장명      102662 non-null  object
#  4   메뉴명       102662 non-null  object
#  5   요일        102662 non-null  int32
#  6   월         102662 non-null  int32
#  7   주말여부      102662 non-null  int64
# dtypes: datetime64[ns](1), int32(2), int64(2), object(3)
# memory usage: 6.3+ MB
# None

# %%
print((train['매출수량'] < 0).sum())
print(train['매출수량'].describe())
# Out:
# 0
# count    102662.000000
# mean         10.656134
# std          41.889051
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           4.000000
# max        1372.000000
# Name: 매출수량, dtype: float64

# %% [markdown]
# | 지표         | 값       | 해석                             |
# | ---------- | ------- | ------------------------------ |
# | **min**    | `-80`   | ❗ **음수 매출 존재 → 비정상 데이터 (이상치)** |
# | **max**    | `1372`  | 상위 극단값 존재 (정상일 수도 있음)          |
# | **median** | `0`     | 전체의 절반 이상이 **판매량 0**           |
# | **mean**   | `10.65` | 평균은 있지만 왜곡 가능성 높음              |
# | **std**    | `41.88` | 표준편차 큼 → 데이터 분산 심함             |
# | **75%**    | `4`     | 75% 구간까지도 매출 4 이하              |

# %%
# 음수 매출 데이터를 가진 행만 필터링
negative_sales = train[train['매출수량'] < 0]

# 확인
print(f"음수 매출수량을 가진 행 수: {len(negative_sales)}")
display(negative_sales)
# Out:
# 음수 매출수량을 가진 행 수: 0
# Empty DataFrame
# Columns: [영업일자, 영업장명_메뉴명, 매출수량, 영업장명, 메뉴명, 요일, 월, 주말여부]
# Index: []

# %%
print((train['매출수량'] == 0).sum())
# Out:
# 54034

# %%
menu_total = train.groupby("영업장명_메뉴명").size()
menu_zeros = train[train["매출수량"] == 0].groupby("영업장명_메뉴명").size()

zero_ratio_by_menu = (menu_zeros / menu_total).fillna(0).sort_values(ascending=False)

# 상위 10개 출력
print(zero_ratio_by_menu.head(10))
# Out:
# 영업장명_메뉴명
# 담하_(단체) 생목살 김치전골 2.0    0.866541
# 담하_문막 복분자 칵테일           0.853383
# 담하_명인안동소주               0.853383
# 담하_(단체) 은이버섯 갈비탕        0.842105
# 라그로타_모둠 해산물 플래터         0.842105
# 미라시아_공깃밥                0.836466
# 카페테리아_진사골 설렁탕           0.832707
# 담하_(단체) 공깃밥             0.825188
# 미라시아_잭 애플 토닉            0.813910
# 연회장_마라샹궈                0.802632
# dtype: float64

# %%
# 80% 이상인 메뉴 필터링
to_remove = zero_ratio_by_menu[zero_ratio_by_menu >= 0.8].index
print(f"0 비율이 80% 이상인 메뉴 수: {len(to_remove)}")
# Out:
# 0 비율이 80% 이상인 메뉴 수: 10

# %%
# 원본 train에서 해당 메뉴 제외
train = train[~train["영업장명_메뉴명"].isin(to_remove)].copy()

# %%
print("제거 후 전체 샘플 수:", len(train))
print("제거 후 매출 0 샘플 수:", (train["매출수량"] == 0).sum())
print("0 비율:", (train["매출수량"] == 0).mean())
# Out:
# 제거 후 전체 샘플 수: 97342
# 제거 후 매출 0 샘플 수: 49582
# 0 비율: 0.5093587557272298

# %%
# 1. 매출 0인 샘플과 0이 아닌 샘플 분리
zero_df = train[train['매출수량'] == 0]
nonzero_df = train[train['매출수량'] > 0]

print(f"0 매출 샘플 수: {len(zero_df)}")
print(f"비-0 매출 샘플 수: {len(nonzero_df)}")
# Out:
# 0 매출 샘플 수: 49582
# 비-0 매출 샘플 수: 47760

# %%
# 2. 매출 0 샘플 중 일부만 사용 (예: 30%)
zero_frac = 0.3  # 비율 조절 가능
sampled_zero_df = zero_df.sample(frac=zero_frac, random_state=42)

print(f"샘플링한 0 샘플 수: {len(sampled_zero_df)}")
# Out:
# 샘플링한 0 샘플 수: 14875

# %%
# 3. 다시 합치기
train_downsampled = pd.concat([nonzero_df, sampled_zero_df]).sort_values("영업일자").reset_index(drop=True)

print(f"Downsampling 이후 전체 샘플 수: {len(train_downsampled)}")
print(f"Downsampling 이후 0 매출 비율: {(train_downsampled['매출수량'] == 0).mean():.2%}")
# Out:
# Downsampling 이후 전체 샘플 수: 62635
# Downsampling 이후 0 매출 비율: 23.75%

# %%
train_downsampled.to_csv("train_downsampled.csv", index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumBarunGothic'  # Colab

sns.histplot(train_downsampled['매출수량'], bins=50)
plt.title("Downsampled 매출수량 분포")
plt.xlabel("매출수량")
plt.ylabel("빈도")
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.

# %%
def create_time_features(df, lag_days=[1, 7], rolling_windows=[7]):
    """
    df: DataFrame (train_downsampled 기준)
    lag_days: 생성할 lag 일수 리스트
    rolling_windows: rolling mean 계산할 기간 리스트
    """

    df = df.sort_values(['영업장명_메뉴명', '영업일자']).copy()

    for lag in lag_days:
        df[f'lag_{lag}'] = df.groupby('영업장명_메뉴명')['매출수량'].shift(lag)
        df[f'diff_{lag}'] = df[f'lag_{lag}'] - df.groupby('영업장명_메뉴명')['매출수량'].shift(lag + 1)

    for window in rolling_windows:
        df[f'rolling_{window}_mean'] = (
            df.groupby('영업장명_메뉴명')['매출수량']
            .shift(1)  # 현재 값 포함 X
            .rolling(window, min_periods=1)
            .mean()
            .reset_index(0, drop=True)
        )

    return df

# %%
# 예: lag_1, lag_7 / rolling 7일 평균 생성
train_fe = create_time_features(train_downsampled,
                                lag_days=[1, 7],
                                rolling_windows=[7])

# %%
train_fe = train_fe.dropna().reset_index(drop=True)

# %%
train_fe.head(5)
# Out:
#         영업일자            영업장명_메뉴명  매출수량        영업장명      메뉴명  요일  월  주말여부  \
# 0 2023-01-23  느티나무 셀프BBQ_1인 수저세트     4  느티나무 셀프BBQ  1인 수저세트   0  1     0
# 1 2023-01-24  느티나무 셀프BBQ_1인 수저세트     2  느티나무 셀프BBQ  1인 수저세트   1  1     0
# 2 2023-01-27  느티나무 셀프BBQ_1인 수저세트     8  느티나무 셀프BBQ  1인 수저세트   4  1     0
# 3 2023-01-28  느티나무 셀프BBQ_1인 수저세트     0  느티나무 셀프BBQ  1인 수저세트   5  1     1
# 4 2023-01-29  느티나무 셀프BBQ_1인 수저세트     8  느티나무 셀프BBQ  1인 수저세트   6  1     1
#
#    lag_1  diff_1  lag_7  diff_7  rolling_7_mean
# 0    8.0     8.0    0.0     0.0        0.000000
# 1    4.0    -4.0    0.0     0.0        3.571429
# 2    2.0    -2.0    0.0     0.0        1.142857
# 3    8.0     6.0    0.0     0.0        0.285714
# 4    0.0    -8.0    0.0     0.0        0.333333

# %%
# 담하 / 미라시아 업장 데이터만 추출
target_places = ['담하', '미라시아']
filtered = train[train['영업장명'].isin(target_places)]

# 확인
filtered['영업장명'].value_counts()
# Out:
# 영업장명
# 담하      19684
# 미라시아    15426
# Name: count, dtype: int64

# %% [markdown]
# 전체 파이프라인 순서
#
# LightGBM 모델을 메인으로 학습
#
# train_fe 사용
#
# feature importance로 분석
#
# LightGBM 성능 낮은 메뉴군 → Prophet 등으로 별도 처리
#
# 또는 앙상블 구조로 soft voting
#
# → 제출 시에는 모든 결과를 하나의 submission.csv로 정리

# %% [markdown]
# LightGBM 학습 & 예측

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import numpy as np
plt.rcParams['font.family'] = 'NanumBarunGothic'  # Colab

# 1. 학습 대상 feature/target
features = ['요일', '월', '주말여부', 'lag_1', 'lag_7', 'diff_1', 'diff_7', 'rolling_7_mean']
target = '매출수량'

# 2. train/val split (random이 아니라 날짜 기반으로 나눠도 OK)
X_train, X_val, y_train, y_val = train_test_split(train_fe[features], train_fe[target], test_size=0.2, random_state=42)

# 3. LGBM Dataset 구성
lgb_train = lgb.Dataset(X_train, y_train)
lgb_val = lgb.Dataset(X_val, y_val, reference=lgb_train)

# 4. 하이퍼파라미터
params = {
    'objective': 'regression',
    'metric': 'mae',
    'learning_rate': 0.05,
    'verbosity': -1,
    'seed': 42
}

# 5. 모델 학습
model = lgb.train(params,
                  lgb_train,
                  num_boost_round=1000,
                  valid_sets=[lgb_train, lgb_val]
                  #early_stopping_rounds=50, # early_stopping_rounds는 lgb.train이 아닌 fit() 메서드에서 사용됩니다.
                  #verbose_eval=100) # verbose_eval도 lgb.train() 함수에서 직접 사용되지 않습니다.
                 )

# 6. feature importance 확인
lgb.plot_importance(model, max_num_features=15)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.

# %% [markdown]
# LightGBM으로 test 예측 수행

# %%
import glob
import pandas as pd
from tqdm import tqdm

# 테스트 결과 저장
lgb_preds = []

# 테스트 셋 불러오기
test_files = sorted(glob.glob("test/TEST_*.csv"))

for path in tqdm(test_files):
    test_df = pd.read_csv(path, parse_dates=['영업일자'])
    test_df[['영업장명', '메뉴명']] = test_df['영업장명_메뉴명'].str.split('_', n=1, expand=True)

    # 동일한 feature 생성 과정
    test_df = create_time_features(test_df,
                                   lag_days=[1, 7],
                                   rolling_windows=[7])
    test_df['요일'] = test_df['영업일자'].dt.dayofweek
    test_df['월'] = test_df['영업일자'].dt.month
    test_df['주말여부'] = test_df['요일'].apply(lambda x: 1 if x >= 5 else 0)

    test_df = test_df.dropna().reset_index(drop=True)
    test_df['pred'] = model.predict(test_df[features])
    test_df['pred'] = np.clip(test_df['pred'], 0, None)  # 음수 방지

    # 7일 예측만 추출
    menu_keys = test_df['영업장명_메뉴명'].unique()
    for menu in menu_keys:
        sub_df = test_df[test_df['영업장명_메뉴명'] == menu]
        last_7 = sub_df.sort_values('영업일자')['pred'][-7:].round().astype(int).tolist()
        test_id = path.split('/')[-1].replace('.csv', '') + '_' + menu
        lgb_preds.append([test_id, ','.join(map(str, last_7))])

# DataFrame으로 변환
lgb_df = pd.DataFrame(lgb_preds, columns=['id', 'sales'])
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.36it/s]

# %%
lgb_df.head()  # 예측 결과 확인
lgb_df.to_csv("lightgbm_submission.csv", index=False)

# %%
import pandas as pd

# 1. LightGBM 결과 불러오기
lgb_df = pd.read_csv("lightgbm_submission.csv")

# 2. ID에서 테스트셋 번호와 메뉴명 추출
lgb_df[['test_id', 'menu']] = lgb_df['id'].str.extract(r'(TEST_\d+)_([^,]+)')

# 3. sales 컬럼을 리스트로 변환
lgb_df['sales'] = lgb_df['sales'].apply(lambda x: list(map(int, x.split(','))))

# 4. sales 리스트를 7행으로 펼치기
expanded = lgb_df.explode('sales')

# 5. 영업일자 부여 (TEST_00+1일 ~ TEST_00+7일)
expanded['day_offset'] = expanded.groupby('id').cumcount()
expanded['영업일자'] = expanded['test_id'] + '+' + (expanded['day_offset'] + 1).astype(str) + '일'

# 6. 피벗 (row: 영업일자, col: 메뉴, val: sales)
pivot_df = expanded.pivot(index='영업일자', columns='menu', values='sales').reset_index()

# 7. sample_submission 순서에 맞게 열 정렬
sample = pd.read_csv("/content/sample_submission.csv")
final_df = pd.DataFrame(columns=sample.columns)
final_df['영업일자'] = pivot_df['영업일자']
for col in sample.columns[1:]:
    if col in pivot_df.columns:
        final_df[col] = pivot_df[col]
    else:
        final_df[col] = 0  # 없는 경우는 0으로 채움

# 8. 최종 제출 파일 저장
final_df.to_csv("lightgbm_submission1.csv", index=False)

# %%
import pandas as pd
import numpy as np
import glob

prophet_candidates = []

# 최종 제출 데이터프레임 컬럼 리스트
submission_columns = final_df.columns.tolist()
menu_columns = [col for col in submission_columns if col != "영업일자"]

# 예측 대상일자 리스트 (예: 마지막 7일)
predict_days = final_df["영업일자"].unique().tolist()

for path in sorted(glob.glob("/content/test/TEST_*.csv")):
    test_df = pd.read_csv(path)

    for menu in test_df["영업장명_메뉴명"].unique():
        recent_sales = test_df[test_df["영업장명_메뉴명"] == menu]["매출수량"]
        recent_mean = recent_sales.mean()

        if menu not in menu_columns:
            print(f"Warning: Menu '{menu}' not found in final_df. Skipping Prophet candidate check.")
            continue

        try:
            # 예측값 추출
            pred = final_df[menu].values
            pred_mean = np.mean(pred)
            pred_std = np.std(pred)

            # 기준 1: 전부 0 예측
            if np.all(pred == 0) and recent_mean > 5:
                prophet_candidates.append(menu)
                continue

            # 기준 2: 예측값이 너무 튐
            if pred_std > 30:
                prophet_candidates.append(menu)
                continue

            # 기준 3: 평균 차이 큼
            if recent_mean > 0 and abs(pred_mean - recent_mean) / recent_mean > 0.8:
                prophet_candidates.append(menu)
                continue

        except Exception as e:
            print(f"[ERROR] Menu '{menu}' 예측 처리 중 오류 발생: {e}")
            continue

# 중복 제거
prophet_candidates = list(set(prophet_candidates))
print(f"\n✅ Prophet 후보 메뉴 수: {len(prophet_candidates)}개")
print("Prophet Candidates 예시:", prophet_candidates[:10])
# Out:
# ✅ Prophet 후보 메뉴 수: 182개
# Prophet Candidates 예시: ['느티나무 셀프BBQ_햇반', '미라시아_코카콜라(제로)', '연회장_매콤 무뼈닭발&계란찜', '담하_라면사리', '미라시아_(단체)브런치주중 36,000', '연회장_Conference L1', '담하_황태해장국', '라그로타_Open Food', '담하_한우 미역국 정식', '라그로타_해산물 토마토 리조또']

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.11/dist-packages (1.1.7)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.11/dist-packages (from prophet) (0.77)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)

# %%
# !pip install --upgrade cmdstanpy
# Out:
# Requirement already satisfied: cmdstanpy in /usr/local/lib/python3.11/dist-packages (1.2.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from cmdstanpy) (2.2.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from cmdstanpy) (4.67.1)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->cmdstanpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->cmdstanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->cmdstanpy) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->cmdstanpy) (1.17.0)

# %%
from prophet import Prophet

for test_file in sorted(glob.glob("/content/test/TEST_*.csv")):
    test_df = pd.read_csv(test_file)

    # 날짜 형식 변환 필수!
    test_df["영업일자"] = pd.to_datetime(test_df["영업일자"])
    pred_date_start = test_df["영업일자"].max() + pd.Timedelta(days=1)

    for menu in test_df["영업장명_메뉴명"].unique():
        if menu not in prophet_candidates:
            continue

        ts_df = test_df[test_df["영업장명_메뉴명"] == menu][["영업일자", "매출수량"]]
        ts_df = ts_df.rename(columns={"영업일자": "ds", "매출수량": "y"})

        if len(ts_df) < 10:
            continue  # 데이터 부족하면 skip

        model = Prophet(yearly_seasonality=False, weekly_seasonality=True, daily_seasonality=False)
        model.fit(ts_df)

        future = model.make_future_dataframe(periods=7)
        forecast = model.predict(future)
        yhat = forecast.tail(7)["yhat"].clip(lower=0).round().tolist()

        # 날짜 범위 가져오기
        pred_dates = forecast.tail(7)["ds"].dt.strftime("%Y-%m-%d").tolist()

        # final_df에서 해당 날짜/메뉴에 해당하는 위치를 찾아 덮어쓰기
        for day, y in zip(pred_dates, yhat):
            final_df.loc[final_df["영업일자"] == day, menu] = y
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ve856xmj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30790', 'data', 'file=/tmp/tmpkc_cch9m/06742490.json', 'init=/tmp/tmpkc_cch9m/ve856xmj.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelsvm2elos/prophet_model-20250801105753.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/we_bvfy_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/neo37g9n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76907', 'data', 'file=/tmp/tmpkc_cch9m/we_bvfy_.json', 'init=/tmp/tmpkc_cch9m/neo37g9n.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modela6w3f4ts/prophet_model-20250801105754.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/l8azkthy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/mi1ys39u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82393', 'data', 'file=/tmp/tmpkc_cch9m/l8azkthy.json', 'init=/tmp/tmpkc_cch9m/mi1ys39u.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelf7w3fuan/prophet_model-20250801105754.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/xddnge48.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/nof8u26a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41036', 'data', 'file=/tmp/tmpkc_cch9m/xddnge48.json', 'init=/tmp/tmpkc_cch9m/nof8u26a.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelz5ivyp0r/prophet_model-20250801105754.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/jt6u16h7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/kzddpce6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5521', 'data', 'file=/tmp/tmpkc_cch9m/jt6u16h7.json', 'init=/tmp/tmpkc_cch9m/kzddpce6.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelpn0u0l9f/prophet_model-20250801105754.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/i66v2bwn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/tqaipn_c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35136', 'data', 'file=/tmp/tmpkc_cch9m/i66v2bwn.json', 'init=/tmp/tmpkc_cch9m/tqaipn_c.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeldzffnlkc/prophet_model-20250801105755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/7gyfjk11.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/4v4jqabv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96817', 'data', 'file=/tmp/tmpkc_cch9m/7gyfjk11.json', 'init=/tmp/tmpkc_cch9m/4v4jqabv.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model_4htvyrz/prophet_model-20250801105755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ya558xkp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/8gh1164o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98105', 'data', 'file=/tmp/tmpkc_cch9m/ya558xkp.json', 'init=/tmp/tmpkc_cch9m/8gh1164o.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model51_y40b4/prophet_model-20250801105755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/jcf7lp54.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/i6aj22h8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32546', 'data', 'file=/tmp/tmpkc_cch9m/jcf7lp54.json', 'init=/tmp/tmpkc_cch9m/i6aj22h8.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelip5bxmg7/prophet_model-20250801105755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/0bxqsz75.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/4r6v_e7c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44241', 'data', 'file=/tmp/tmpkc_cch9m/0bxqsz75.json', 'init=/tmp/tmpkc_cch9m/4r6v_e7c.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeln1t7xd8n/prophet_model-20250801105755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/5sw3w741.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/7h64ive8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80438', 'data', 'file=/tmp/tmpkc_cch9m/5sw3w741.json', 'init=/tmp/tmpkc_cch9m/7h64ive8.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model0qte_6z9/prophet_model-20250801105756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/zzqo6fdf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ycrdlx7c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95260', 'data', 'file=/tmp/tmpkc_cch9m/zzqo6fdf.json', 'init=/tmp/tmpkc_cch9m/ycrdlx7c.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelfhw0y2zj/prophet_model-20250801105756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/mrg1s24_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/efeabd1j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81360', 'data', 'file=/tmp/tmpkc_cch9m/mrg1s24_.json', 'init=/tmp/tmpkc_cch9m/efeabd1j.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelms8a344e/prophet_model-20250801105756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/70c9u_cm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/3zj6wfyn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94191', 'data', 'file=/tmp/tmpkc_cch9m/70c9u_cm.json', 'init=/tmp/tmpkc_cch9m/3zj6wfyn.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modela6qhvw7c/prophet_model-20250801105756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/oju7oti3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/c1j85uqm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61337', 'data', 'file=/tmp/tmpkc_cch9m/oju7oti3.json', 'init=/tmp/tmpkc_cch9m/c1j85uqm.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeliko7r2_4/prophet_model-20250801105756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/owplsq_q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/vauj4fkc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22005', 'data', 'file=/tmp/tmpkc_cch9m/owplsq_q.json', 'init=/tmp/tmpkc_cch9m/vauj4fkc.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelgr6iboup/prophet_model-20250801105757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/fgtr6x1s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/51qwc7yb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57100', 'data', 'file=/tmp/tmpkc_cch9m/fgtr6x1s.json', 'init=/tmp/tmpkc_cch9m/51qwc7yb.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelcb153o_4/prophet_model-20250801105757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/wnrmv7bw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/wq230lwa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86057', 'data', 'file=/tmp/tmpkc_cch9m/wnrmv7bw.json', 'init=/tmp/tmpkc_cch9m/wq230lwa.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelb3r6z2a6/prophet_model-20250801105757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/__7o6lqd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/yfr5owla.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79465', 'data', 'file=/tmp/tmpkc_cch9m/__7o6lqd.json', 'init=/tmp/tmpkc_cch9m/yfr5owla.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model6xcrh9ti/prophet_model-20250801105757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/bqbmpqzv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/wo9kih2c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72654', 'data', 'file=/tmp/tmpkc_cch9m/bqbmpqzv.json', 'init=/tmp/tmpkc_cch9m/wo9kih2c.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model2wfoh0jc/prophet_model-20250801105757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/cdfc1nnn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ktr__wch.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6640', 'data', 'file=/tmp/tmpkc_cch9m/cdfc1nnn.json', 'init=/tmp/tmpkc_cch9m/ktr__wch.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelviit9ijb/prophet_model-20250801105758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/6r8rd3ts.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/m0xjwj9c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56322', 'data', 'file=/tmp/tmpkc_cch9m/6r8rd3ts.json', 'init=/tmp/tmpkc_cch9m/m0xjwj9c.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelog82bsvq/prophet_model-20250801105758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/kpspumeb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/gfbmxyax.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86578', 'data', 'file=/tmp/tmpkc_cch9m/kpspumeb.json', 'init=/tmp/tmpkc_cch9m/gfbmxyax.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelubkzp40t/prophet_model-20250801105758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/w944i19e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/j3zy5f9y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33443', 'data', 'file=/tmp/tmpkc_cch9m/w944i19e.json', 'init=/tmp/tmpkc_cch9m/j3zy5f9y.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modely1xxla2v/prophet_model-20250801105758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/lj7jsshm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/83cl4cfw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9117', 'data', 'file=/tmp/tmpkc_cch9m/lj7jsshm.json', 'init=/tmp/tmpkc_cch9m/83cl4cfw.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelcz1b_p6l/prophet_model-20250801105758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/cb_u7a5d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/k22rbf63.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59287', 'data', 'file=/tmp/tmpkc_cch9m/cb_u7a5d.json', 'init=/tmp/tmpkc_cch9m/k22rbf63.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelffqzq15o/prophet_model-20250801105759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/sjk3k7eo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/h5zmi8_e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94302', 'data', 'file=/tmp/tmpkc_cch9m/sjk3k7eo.json', 'init=/tmp/tmpkc_cch9m/h5zmi8_e.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model5ze7qfrc/prophet_model-20250801105759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/2ovxwcie.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ugf8f0ow.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31904', 'data', 'file=/tmp/tmpkc_cch9m/2ovxwcie.json', 'init=/tmp/tmpkc_cch9m/ugf8f0ow.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelv3dcauzh/prophet_model-20250801105759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/weixd69h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/tttrrpjr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59772', 'data', 'file=/tmp/tmpkc_cch9m/weixd69h.json', 'init=/tmp/tmpkc_cch9m/tttrrpjr.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeluoe6sf20/prophet_model-20250801105759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/7xvwm7j_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/22ld4b08.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40123', 'data', 'file=/tmp/tmpkc_cch9m/7xvwm7j_.json', 'init=/tmp/tmpkc_cch9m/22ld4b08.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelrwiz01kh/prophet_model-20250801105759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:57:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:57:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/6p0tsbnh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/c70o_qja.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27905', 'data', 'file=/tmp/tmpkc_cch9m/6p0tsbnh.json', 'init=/tmp/tmpkc_cch9m/c70o_qja.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelmbg66t6r/prophet_model-20250801105800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/h7ebvc2a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/6t2948on.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78458', 'data', 'file=/tmp/tmpkc_cch9m/h7ebvc2a.json', 'init=/tmp/tmpkc_cch9m/6t2948on.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelbr1e3l2j/prophet_model-20250801105800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ox2frrtn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/_3wwz7c5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57516', 'data', 'file=/tmp/tmpkc_cch9m/ox2frrtn.json', 'init=/tmp/tmpkc_cch9m/_3wwz7c5.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelbf0yepk4/prophet_model-20250801105800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/zgb5kozo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/i5fyqw4d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45774', 'data', 'file=/tmp/tmpkc_cch9m/zgb5kozo.json', 'init=/tmp/tmpkc_cch9m/i5fyqw4d.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model26hjdsy0/prophet_model-20250801105800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/e1yj5rp4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ejiuw7cv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46418', 'data', 'file=/tmp/tmpkc_cch9m/e1yj5rp4.json', 'init=/tmp/tmpkc_cch9m/ejiuw7cv.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelg5_qs9g1/prophet_model-20250801105800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/9u54qn6a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/yn1dq9qk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30473', 'data', 'file=/tmp/tmpkc_cch9m/9u54qn6a.json', 'init=/tmp/tmpkc_cch9m/yn1dq9qk.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeluh7_cuq8/prophet_model-20250801105801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/v06nj13g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/2oznccpj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52160', 'data', 'file=/tmp/tmpkc_cch9m/v06nj13g.json', 'init=/tmp/tmpkc_cch9m/2oznccpj.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeldd148_2n/prophet_model-20250801105801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/hjfn9d2n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/h9rfbtib.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15960', 'data', 'file=/tmp/tmpkc_cch9m/hjfn9d2n.json', 'init=/tmp/tmpkc_cch9m/h9rfbtib.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelkl2n3zyt/prophet_model-20250801105801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/y8r_q9a8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/p5bvla8x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46009', 'data', 'file=/tmp/tmpkc_cch9m/y8r_q9a8.json', 'init=/tmp/tmpkc_cch9m/p5bvla8x.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelg7ee4_yj/prophet_model-20250801105802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ne52295v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/i3mz_pwt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78180', 'data', 'file=/tmp/tmpkc_cch9m/ne52295v.json', 'init=/tmp/tmpkc_cch9m/i3mz_pwt.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelvbreog84/prophet_model-20250801105802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/o0nipsna.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/1eus5de5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20421', 'data', 'file=/tmp/tmpkc_cch9m/o0nipsna.json', 'init=/tmp/tmpkc_cch9m/1eus5de5.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelj7xwp4gi/prophet_model-20250801105802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/es7v362w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/0k747xtu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35350', 'data', 'file=/tmp/tmpkc_cch9m/es7v362w.json', 'init=/tmp/tmpkc_cch9m/0k747xtu.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modell71wb7wn/prophet_model-20250801105803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/8gqihqt8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/prtytrt6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63919', 'data', 'file=/tmp/tmpkc_cch9m/8gqihqt8.json', 'init=/tmp/tmpkc_cch9m/prtytrt6.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelz7nu76yr/prophet_model-20250801105803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/s3yvimuv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/6pvk2n_x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81238', 'data', 'file=/tmp/tmpkc_cch9m/s3yvimuv.json', 'init=/tmp/tmpkc_cch9m/6pvk2n_x.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_models5rkutq6/prophet_model-20250801105803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/nmxdmh3l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/uucbnueq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7003', 'data', 'file=/tmp/tmpkc_cch9m/nmxdmh3l.json', 'init=/tmp/tmpkc_cch9m/uucbnueq.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model8cui88ji/prophet_model-20250801105803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/re5er3zq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/34fe773e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20908', 'data', 'file=/tmp/tmpkc_cch9m/re5er3zq.json', 'init=/tmp/tmpkc_cch9m/34fe773e.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model0e8k4g33/prophet_model-20250801105804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/cats3pug.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/_9hypwab.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83128', 'data', 'file=/tmp/tmpkc_cch9m/cats3pug.json', 'init=/tmp/tmpkc_cch9m/_9hypwab.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modell8bbca3j/prophet_model-20250801105804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/eahv05cd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/fjls2_cg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81800', 'data', 'file=/tmp/tmpkc_cch9m/eahv05cd.json', 'init=/tmp/tmpkc_cch9m/fjls2_cg.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelf_6pib8d/prophet_model-20250801105804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/wb3bxu4r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/9_gnx_0f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23909', 'data', 'file=/tmp/tmpkc_cch9m/wb3bxu4r.json', 'init=/tmp/tmpkc_cch9m/9_gnx_0f.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model79ozyipj/prophet_model-20250801105804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/bsbcd0cm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/94g6xll7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45810', 'data', 'file=/tmp/tmpkc_cch9m/bsbcd0cm.json', 'init=/tmp/tmpkc_cch9m/94g6xll7.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelufqddnri/prophet_model-20250801105805.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/2vumnhh6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/m0uw9w_z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55224', 'data', 'file=/tmp/tmpkc_cch9m/2vumnhh6.json', 'init=/tmp/tmpkc_cch9m/m0uw9w_z.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelc08i94ak/prophet_model-20250801105805.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/_twt1k1w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/3g5ojgu4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98590', 'data', 'file=/tmp/tmpkc_cch9m/_twt1k1w.json', 'init=/tmp/tmpkc_cch9m/3g5ojgu4.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modele9dcoo6y/prophet_model-20250801105805.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/4uhvk17f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/v5pmuhp1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99835', 'data', 'file=/tmp/tmpkc_cch9m/4uhvk17f.json', 'init=/tmp/tmpkc_cch9m/v5pmuhp1.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeln4i7xnnt/prophet_model-20250801105805.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/gsrtlx9q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/2c2u8ay0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79147', 'data', 'file=/tmp/tmpkc_cch9m/gsrtlx9q.json', 'init=/tmp/tmpkc_cch9m/2c2u8ay0.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelt2kp2yhh/prophet_model-20250801105805.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/rtfrqapr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/kegl6owq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42214', 'data', 'file=/tmp/tmpkc_cch9m/rtfrqapr.json', 'init=/tmp/tmpkc_cch9m/kegl6owq.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeljo7efwrw/prophet_model-20250801105806.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/25ef_5x2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/wts_ajlp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60167', 'data', 'file=/tmp/tmpkc_cch9m/25ef_5x2.json', 'init=/tmp/tmpkc_cch9m/wts_ajlp.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model3iq93ryg/prophet_model-20250801105806.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/yjd6nvgg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/3xs998je.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87861', 'data', 'file=/tmp/tmpkc_cch9m/yjd6nvgg.json', 'init=/tmp/tmpkc_cch9m/3xs998je.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelx4miseqf/prophet_model-20250801105806.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:58:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:58:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ny7pq5cu.json
# ...
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/4xj4jduc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/nitk56gi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48366', 'data', 'file=/tmp/tmpkc_cch9m/4xj4jduc.json', 'init=/tmp/tmpkc_cch9m/nitk56gi.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelcfq3eowp/prophet_model-20250801105938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/u8tni5y9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ybrpeb1h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82196', 'data', 'file=/tmp/tmpkc_cch9m/u8tni5y9.json', 'init=/tmp/tmpkc_cch9m/ybrpeb1h.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelw07ut_gj/prophet_model-20250801105938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/jlvbtqmg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/01owpwc6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19077', 'data', 'file=/tmp/tmpkc_cch9m/jlvbtqmg.json', 'init=/tmp/tmpkc_cch9m/01owpwc6.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelvlmti_xs/prophet_model-20250801105938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/jnhhk1wv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/y2ha_eti.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37734', 'data', 'file=/tmp/tmpkc_cch9m/jnhhk1wv.json', 'init=/tmp/tmpkc_cch9m/y2ha_eti.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelg0woypb8/prophet_model-20250801105938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/1_m5sgor.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/5fc_0sm5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55177', 'data', 'file=/tmp/tmpkc_cch9m/1_m5sgor.json', 'init=/tmp/tmpkc_cch9m/5fc_0sm5.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelx688iis5/prophet_model-20250801105939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/y82yu2_s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/26xn00pg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=671', 'data', 'file=/tmp/tmpkc_cch9m/y82yu2_s.json', 'init=/tmp/tmpkc_cch9m/26xn00pg.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_models2b27z01/prophet_model-20250801105939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/u9h62075.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/gimr632e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57541', 'data', 'file=/tmp/tmpkc_cch9m/u9h62075.json', 'init=/tmp/tmpkc_cch9m/gimr632e.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeleo2o3uho/prophet_model-20250801105939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/gjz3wez3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/0au8r4ck.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79615', 'data', 'file=/tmp/tmpkc_cch9m/gjz3wez3.json', 'init=/tmp/tmpkc_cch9m/0au8r4ck.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modeluqxcgbfq/prophet_model-20250801105939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/fbp8u2s1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/dvlfrrj3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98179', 'data', 'file=/tmp/tmpkc_cch9m/fbp8u2s1.json', 'init=/tmp/tmpkc_cch9m/dvlfrrj3.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model5uht659e/prophet_model-20250801105939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/fz9715uq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/qnowtvw1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86443', 'data', 'file=/tmp/tmpkc_cch9m/fz9715uq.json', 'init=/tmp/tmpkc_cch9m/qnowtvw1.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model_1i_s0yz/prophet_model-20250801105940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/b3v5w4c2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/bnr3599v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10199', 'data', 'file=/tmp/tmpkc_cch9m/b3v5w4c2.json', 'init=/tmp/tmpkc_cch9m/bnr3599v.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modela_ebwro4/prophet_model-20250801105940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/5airvvc1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/o5do18mb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67441', 'data', 'file=/tmp/tmpkc_cch9m/5airvvc1.json', 'init=/tmp/tmpkc_cch9m/o5do18mb.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model7b7ijf9_/prophet_model-20250801105940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/5kfzeksn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/vzoms7rq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84912', 'data', 'file=/tmp/tmpkc_cch9m/5kfzeksn.json', 'init=/tmp/tmpkc_cch9m/vzoms7rq.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelcjrmwhb4/prophet_model-20250801105940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/t872akeo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/vfwcx7y7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29416', 'data', 'file=/tmp/tmpkc_cch9m/t872akeo.json', 'init=/tmp/tmpkc_cch9m/vfwcx7y7.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelq_1xa70q/prophet_model-20250801105940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ymihz5s3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/r12ca5xb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91599', 'data', 'file=/tmp/tmpkc_cch9m/ymihz5s3.json', 'init=/tmp/tmpkc_cch9m/r12ca5xb.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model0evhase7/prophet_model-20250801105941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/e0kz_kzq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/mrtzepeb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13837', 'data', 'file=/tmp/tmpkc_cch9m/e0kz_kzq.json', 'init=/tmp/tmpkc_cch9m/mrtzepeb.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_modelfoazxaiz/prophet_model-20250801105941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/x3ns3f3o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/4kt45t9p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61315', 'data', 'file=/tmp/tmpkc_cch9m/x3ns3f3o.json', 'init=/tmp/tmpkc_cch9m/4kt45t9p.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model6x2j1_xs/prophet_model-20250801105941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/ke2mzuyo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/qxviel30.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38436', 'data', 'file=/tmp/tmpkc_cch9m/ke2mzuyo.json', 'init=/tmp/tmpkc_cch9m/qxviel30.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model9equ0zxi/prophet_model-20250801105941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/8r8hlb_q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkc_cch9m/bp6aso03.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36498', 'data', 'file=/tmp/tmpkc_cch9m/8r8hlb_q.json', 'init=/tmp/tmpkc_cch9m/bp6aso03.json', 'output', 'file=/tmp/tmpkc_cch9m/prophet_model74xpmfd4/prophet_model-20250801105941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:59:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:59:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# 모든 예측값을 정수로 반올림 후 저장
final_df.iloc[:, 1:] = final_df.iloc[:, 1:].round().astype(int)

# %%
final_df.to_csv("lgbm_prophet182_hybrid_submission.csv", index=False, encoding="utf-8-sig")
